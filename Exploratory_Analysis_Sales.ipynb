# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df[df['City']=='Henderson']
# Out:
#            Ship Mode      Segment        Country       City     State  \
# 0       Second Class     Consumer  United States  Henderson  Kentucky
# 1       Second Class     Consumer  United States  Henderson  Kentucky
# 538   Standard Class     Consumer  United States  Henderson  Kentucky
# 539   Standard Class     Consumer  United States  Henderson  Kentucky
# 996   Standard Class     Consumer  United States  Henderson  Kentucky
# 997   Standard Class     Consumer  United States  Henderson  Kentucky
# 998   Standard Class     Consumer  United States  Henderson  Kentucky
# 999   Standard Class     Consumer  United States  Henderson  Kentucky
# 1866     First Class    Corporate  United States  Henderson    Nevada
# 2321    Second Class    Corporate  United States  Henderson  Kentucky
# 2322    Second Class    Corporate  United States  Henderson  Kentucky
# 2323    Second Class    Corporate  United States  Henderson  Kentucky
# ...

# %%
len(df)
# Out:
# 9994

# %%
df.State.value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df.City.value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
sns.set_theme(style="whitegrid")
sns.barplot(x="State", y="Profit", data=df)

# %%
df2=df.groupby('State')['Profit'].sum().reset_index(name='Sum Profit')

# %%
df2.head()
# Out:
#         State  Sum Profit
# 0     Alabama   5786.8253
# 1     Arizona  -3427.9246
# 2    Arkansas   4008.6871
# 3  California  76381.3871
# 4    Colorado  -6527.8579

# %%
df2[df2['Sum Profit']<=0].State.unique()
# Out:
# array(['Arizona', 'Colorado', 'Florida', 'Illinois', 'North Carolina',
#        'Ohio', 'Oregon', 'Pennsylvania', 'Tennessee', 'Texas'],
#       dtype=object)

# %%
# As you can see the toral profit gained through all transactions in these states is below zero    , so i would start by examining why and improving profits in these states.

# %%
df3=df.groupby('City')['Profit'].sum().reset_index(name='Sum Profit')

# %%
df3.head()
# Out:
#           City  Sum Profit
# 0     Aberdeen      6.6300
# 1      Abilene     -3.7584
# 2        Akron   -186.6356
# 3  Albuquerque    634.0881
# 4   Alexandria    318.6183

# %%
df3[df3['Sum Profit']<=0].City.unique()
# Out:
# array(['Abilene', 'Akron', 'Allen', 'Allentown', 'Altoona', 'Amarillo',
#        'Aurora', 'Austin', 'Bethlehem', 'Bloomington', 'Boca Raton',
#        'Bolingbrook', 'Bryan', 'Buffalo Grove', 'Burlington',
#        'Carol Stream', 'Carrollton', 'Champaign', 'Charlotte', 'Chicago',
#        'Clarksville', 'Cleveland', 'College Station', 'Colorado Springs',
#        'Commerce City', 'Concord', 'Corpus Christi', 'Cuyahoga Falls',
#        'Dallas', 'Daytona Beach', 'Deer Park', 'Denver', 'Des Plaines',
#        'Dublin', 'El Paso', 'Elmhurst', 'Elyria', 'Fort Collins',
#        'Fort Lauderdale', 'Frankfort', 'Freeport', 'Frisco', 'Garland',
#        'Gastonia', 'Grand Prairie', 'Greensboro', 'Greenville',
#        'Hamilton', 'Hendersonville', 'Hialeah', 'Hickory',
#        'Highland Park', 'Houston', 'Irving', 'Jacksonville', 'Knoxville',
#        'Lakeland', 'Lancaster', 'Laredo', 'League City', 'Littleton',
# ...

# %%
# As you can see the total profit in these cities is below zero , so as a manager i'll start by investigating why and improve profits in these cities

# %%
df4=df.groupby(by=['City','Region'])['Profit'].sum().reset_index(name='Sum Profit')

# %%
df4.head(30)
# Out:
#                  City   Region  Sum Profit
# 0            Aberdeen  Central      6.6300
# 1             Abilene  Central     -3.7584
# 2               Akron     East   -186.6356
# 3         Albuquerque     West    634.0881
# 4          Alexandria    South    318.6183
# 5               Allen  Central    -39.8775
# 6           Allentown     East   -226.4504
# 7             Altoona     East     -1.1835
# 8            Amarillo  Central   -387.9683
# 9             Anaheim     West   1234.0036
# 10            Andover     East    124.1886
# 11          Ann Arbor  Central    228.9158
# 12            Antioch     West      9.3312
# 13             Apopka    South     54.3634
# 14       Apple Valley  Central      8.9706
# 15       Apple Valley     West    283.6184
# 16           Appleton  Central    554.7663
# 17          Arlington  Central   -254.3886
# 18          Arlington    South   4424.0855
# 19  Arlington Heights  Central      1.2348
# 20             Arvada     West     59.8556
# ...

# %%
df4[df4['Sum Profit']<=0]
# Out:
#           City   Region  Sum Profit
# 1      Abilene  Central     -3.7584
# 2        Akron     East   -186.6356
# 5        Allen  Central    -39.8775
# 6    Allentown     East   -226.4504
# 7      Altoona     East     -1.1835
# ..         ...      ...         ...
# 567   Wheeling  Central   -293.3178
# 573     Wilson    South    -14.3360
# 576  Woodstock  Central    -24.8859
# 580       York     East   -102.1692
# 582       Yuma     West   -465.9909
#
# [131 rows x 3 columns]

# %%
# As you can see the data above indicates that the profits in specific regions in certain cities is below zero,
#that will limit our search so much, So we can start by investigating why we are losing in these areas?
#Is there a competitor for us in these areas?
#Maybe we're not selling our expensive items in these regions?
#After deciding what the problem is , we can work on solutions to it to overall enhance and improve our profits in these regions.
